# %%
import pandas as pd

# %%
pd.__version__ =
# Out:
# '2.2.2'

# %% [markdown]
# i want to 2.0.3 version so install here

# %%
pip install pandas==2.0.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 65.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# don't give space around == its make error

# %%
data = pd.read_csv("/content/drive/MyDrive/Data_cleaning/zomato.csv")

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
data.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# ...

# %%
data.tail(3)
# Out:
#                                                      url  \
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes           phone                    location  \
# 51714         No     NaN      0             NaN                  Whitefield
# ...

# %%
data.shape
# Out:
# (51717, 17)

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %% [markdown]
# 1st way - Filtering Data

# %%
data["reviews_list"]
# Out:
# 0        [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1        [('Rated 4.0', 'RATED\n  Had been here for din...
# 2        [('Rated 3.0', "RATED\n  Ambience is not that ...
# 3        [('Rated 4.0', "RATED\n  Great food and proper...
# 4        [('Rated 4.0', 'RATED\n  Very good restaurant ...
#                                ...
# 51712    [('Rated 5.0', "RATED\n  Food and service are ...
# 51713                                                   []
# 51714                                                   []
# 51715    [('Rated 4.0', 'RATED\n  Nice and friendly pla...
# 51716    [('Rated 5.0', 'RATED\n  Great ambience , look...
# Name: reviews_list, Length: 51717, dtype: object

# %% [markdown]
# if we try see multicolumn in data its show error like this

# %%
data["reviews_list","cuisines"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('reviews_list', 'cuisines')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1367/730046710.py in <cell line: 0>()
# ----> 1 data["reviews_list","cuisines"]
#
# ...

# %% [markdown]
# how to alter this error

# %%
data[["reviews_list","cuisines"]]
# Out:
#                                             reviews_list  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...
# 3      [('Rated 4.0', "RATED\n  Great food and proper...
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...
# ...                                                  ...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...
# 51713                                                 []
# 51714                                                 []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...
#
#                                      cuisines
# 0              North Indian, Mughlai, Chinese
# 1                 Chinese, North Indian, Thai
# 2                      Cafe, Mexican, Italian
# 3                  South Indian, North Indian
# ...

# %% [markdown]
# 2nd way Dropping the columns

# %%
''' 1. deleting reduntant columns
renaming the columns
droping duplicates
cleaning indiviual columns
remove the NAN values from the dataset
check for some more transformations '''

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
columns_to_drop =['url', 'address','votes',
       'phone', 'location', 'rest_type', 'cuisines', 'reviews_list', 'menu_item',
       'listed_in(type)', 'listed_in(city)']

# %%
data.shape
# Out:
# (51717, 17)

# %%
columns_to_keep=['name', 'online_order', 'book_table', 'rate','approx_cost(for two people)','dish_liked']

# %%
len(columns_to_drop)
# Out:
# 11

# %%
len(columns_to_keep)
# Out:
# 6

# %%
columns_to_drop
# Out:
# ['url',
#  'address',
#  'votes',
#  'phone',
#  'location',
#  'rest_type',
#  'cuisines',
#  'reviews_list',
#  'menu_item',
#  'listed_in(type)',
#  'listed_in(city)']

# %%
data.drop(columns=columns_to_drop,inplace=True, errors='ignore')

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
'''  deleting reduntant columns
2.renaming the columns
droping duplicates
cleaning indiviual columns
remove the NAN values from the dataset
check for some more transformations '''

# %%
data.rename(columns={"name":"name1"})
# Out:
#                                                    name1 online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'dish_liked',
#        'approx_cost(for two people)'],
#       dtype='object')

# %% [markdown]
# removing 1 by 1

# %%
from numpy._core.defchararray import capitalize
data.columns[0].capitalize()
# Out:
# 'Name'

# %%
for i in data.columns:
  print(i.capitalize())
# Out:
# Name
# Online_order
# Book_table
# Rate
# Dish_liked
# Approx_cost(for two people)

# %%
from numpy._core.defchararray import capitalize
new_column_names=[]
for i in data.columns:
  new_column_names.append(i.capitalize())

# %%
data.columns = new_column_names

# %%
data.columns
# Out:
# Index(['Name', 'Online_order', 'Book_table', 'Rate', 'Dish_liked',
#        'Approx_cost(for two people)'],
#       dtype='object')

# %%
''' deleting reduntant columns
renaming the columns
3.droping duplicates
cleaning indiviual columns
remove the NAN values from the dataset
check for some more transformations '''

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712     True
# 51713     True
# 51714    False
# 51715     True
# 51716     True
# Length: 51717, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(32808)

# %%
data.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
data.duplicated().tail(15)
# Out:
# 51702     True
# 51703     True
# 51704     True
# 51705     True
# 51706     True
# 51707     True
# 51708     True
# 51709     True
# 51710     True
# 51711     True
# 51712     True
# 51713     True
# 51714    False
# 51715     True
# 51716     True
# dtype: bool

# %%
data.duplicated().head(15)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# dtype: bool

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.duplicated().value_counts()
# Out:
# False    18909
# Name: count, dtype: int64

# %%
''' deleting reduntant columns
renaming the columns
droping duplicates
4.remove the NAN values from the dataset
cleaning indiviual columns
check for some more transformations '''

# %% [markdown]
# checking the duplicates row and how many count have

# %%
data.isna()
# Out:
#         Name  Online_order  Book_table   Rate  Dish_liked  \
# 0      False         False       False  False       False
# 1      False         False       False  False       False
# 2      False         False       False  False       False
# 3      False         False       False  False       False
# 4      False         False       False  False       False
# ...      ...           ...         ...    ...         ...
# 51631  False         False       False  False        True
# 51632  False         False       False  False        True
# 51641  False         False       False  False        True
# 51677  False         False       False  False       False
# 51714  False         False       False   True        True
#
#        Approx_cost(for two people)
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# ...

# %%
data.isna().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rate                            2418
# Dish_liked                     10587
# Approx_cost(for two people)      140
# dtype: int64

# %%
data.isna().value_counts()
# Out:
# Name   Online_order  Book_table  Rate   Dish_liked  Approx_cost(for two people)
# False  False         False       False  False       False                          8250
#                                         True        False                          8142
#                                  True   True        False                          2348
#                                  False  True        True                             57
#                                         False       True                             42
#                                  True   True        True                             40
#                                         False       False                            29
#                                                     True                              1
# Name: count, dtype: int64

# %%
data.dropna()
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51611                                    Chung Wah           No         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
#          Rate                                         Dish_liked  \
# ...

# %%
data.isna().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rate                            2418
# Dish_liked                     10587
# Approx_cost(for two people)      140
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Name                           0
# Online_order                   0
# Book_table                     0
# Rate                           0
# Dish_liked                     0
# Approx_cost(for two people)    0
# dtype: int64

# %%
data
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51611                                    Chung Wah           No         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
#          Rate                                         Dish_liked  \
# ...

# %% [markdown]
# reset_index() resets the DataFrame row numbering back to the default sequential index (0, 1, 2, ...).

# %%
data.reset_index()
# Out:
#       index                                         Name Online_order  \
# 0         0                                        Jalsa          Yes
# 1         1                               Spice Elephant          Yes
# 2         2                              San Churro Cafe          Yes
# 3         3                        Addhuri Udupi Bhojana           No
# 4         4                                Grand Village           No
# ...     ...                                          ...          ...
# 8245  51611                                    Chung Wah           No
# 8246  51617                              Breakfast House           No
# 8247  51620                               Fujian Express          Yes
# 8248  51628  Nook - Aloft Bengaluru Cessna Business Park           No
# 8249  51677                                      Bhagini           No
#
#      Book_table    Rate                                         Dish_liked  \
# ...

# %%
data.reset_index(inplace = True)

# %%
data
# Out:
#       index                                         Name Online_order  \
# 0         0                                        Jalsa          Yes
# 1         1                               Spice Elephant          Yes
# 2         2                              San Churro Cafe          Yes
# 3         3                        Addhuri Udupi Bhojana           No
# 4         4                                Grand Village           No
# ...     ...                                          ...          ...
# 8245  51611                                    Chung Wah           No
# 8246  51617                              Breakfast House           No
# 8247  51620                               Fujian Express          Yes
# 8248  51628  Nook - Aloft Bengaluru Cessna Business Park           No
# 8249  51677                                      Bhagini           No
#
#      Book_table    Rate                                         Dish_liked  \
# ...

# %%
data.drop(columns="index",inplace=True)

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#         Rate                                         Dish_liked  \
# ...

# %%
''' deleting reduntant columns
renaming the columns
droping duplicates
4.remove the NAN values from the dataset
cleaning indiviual columns
check for some more transformations '''

# %%
data["Rate"][14]
# Out:
# '3.9/5'

# %%
type(data["Rate"][14])
# Out:
# str

# %%
data["Rate"]
# Out:
# 0        4.1/5
# 1        4.1/5
# 2        3.8/5
# 3        3.7/5
# 4        3.8/5
#          ...
# 8245    2.5 /5
# 8246    3.6 /5
# 8247    3.8 /5
# 8248    4.2 /5
# 8249    2.5 /5
# Name: Rate, Length: 8250, dtype: object

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#        Rate                                         Dish_liked  \
# ...

# %%
data["Rate"] = data["Rate"].str.replace(" ","")

# %%
data["Rate"] = data["Rate"].str.replace("/"," out of ")

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#               Rate                                         Dish_liked  \
# ...

# %%
''' deleting reduntant columns
renaming the columns
droping duplicates
remove the NAN values from the dataset
5.cleaning indiviual columns
check for some more transformations '''

# %%
data["Online_order"]
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3        No
# 4        No
#        ...
# 8245     No
# 8246     No
# 8247    Yes
# 8248     No
# 8249     No
# Name: Online_order, Length: 8250, dtype: object

# %%
data["Online_order"] = data["Online_order"].apply(lambda x:1 if x=="yes" else 0)

# %%
data.to_csv("Cleaned_csv_file.csv")

# %%
pd.read_csv("Cleaned_csv_file.csv")
# Out:
#       Unnamed: 0                                         Name  Online_order  \
# 0              0                                        Jalsa             0
# 1              1                               Spice Elephant             0
# 2              2                              San Churro Cafe             0
# 3              3                        Addhuri Udupi Bhojana             0
# 4              4                                Grand Village             0
# ...          ...                                          ...           ...
# 8245        8245                                    Chung Wah             0
# 8246        8246                              Breakfast House             0
# 8247        8247                               Fujian Express             0
# 8248        8248  Nook - Aloft Bengaluru Cessna Business Park             0
# 8249        8249                                      Bhagini             0
#
#      Book_table          Rate  \
# ...

# %%
data.to_csv("Cleaned_wo_index.csv",index=False)

# %%
pd.read_csv("Cleaned_wo_index.csv")
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             0        Yes
# 1                                  Spice Elephant             0         No
# 2                                 San Churro Cafe             0         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             0         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %%
data.to_excel("cleaned_excel.xlsx")

# %%
data.to_excel("cleaned_excel_wo_index.xlsx",index=False)

# %%
pd.read_excel("cleaned_excel.xlsx")
# Out:
#       Unnamed: 0                                         Name  Online_order  \
# 0              0                                        Jalsa             0
# 1              1                               Spice Elephant             0
# 2              2                              San Churro Cafe             0
# 3              3                        Addhuri Udupi Bhojana             0
# 4              4                                Grand Village             0
# ...          ...                                          ...           ...
# 8245        8245                                    Chung Wah             0
# 8246        8246                              Breakfast House             0
# 8247        8247                               Fujian Express             0
# 8248        8248  Nook - Aloft Bengaluru Cessna Business Park             0
# 8249        8249                                      Bhagini             0
#
#      Book_table          Rate  \
# ...

# %%
pd.read_excel("cleaned_excel_wo_index.xlsx")
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             0        Yes
# 1                                  Spice Elephant             0         No
# 2                                 San Churro Cafe             0         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             0         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...
